# %% [markdown]
# # Visualize the mean hospitalization rate in France
#
# This notebook allows you to load and plot the data from the COVID-19 dataset extracted from the web.
#
# > It is recommended to run it inside a new Python environement with `pandas` and `matplotlib` installed.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.close("all")

# %%
# Replace the path with your own path
df = pd.read_csv("../airflow/data/mean-incid_hosp-2025-06-30.csv", index_col=0)

# %%
df.head()
# Out:
#             incid_hosp
# date
# 2020-03-18         NaN
# 2020-03-19   22.069307
# 2020-03-20   12.435644
# 2020-03-21   15.247525
# 2020-03-22   15.188119

# %%
plt.figure();
df.plot(figsize=(24, 12))
# Out:
# <Axes: xlabel='date'>
